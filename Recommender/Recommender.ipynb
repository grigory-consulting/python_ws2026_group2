# %%
import pandas as pd
import math

user_data = pd.read_csv("./Recommender/u.data",
                        sep= "\t", 
                        names=["user_id", "movie_id", "rating", "timestamp"],
                        usecols=[0, 1, 2],
                        )
print(user_data)

main_dict = {}

for movie in user_data.movie_id:
    movie_subset = user_data[user_data.movie_id == movie] 

print(movie_subset[["user_id", "rating"]].to_dict())
